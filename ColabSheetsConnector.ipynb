# %%
#criando autenticação via Google
from google.colab import auth
auth.authenticate_user()

#importando biblioteca que conecta com o Google Sheets
import gspread as sheet
from oauth2client.client import GoogleCredentials

# %%
gs = sheet.authorize(GoogleCredentials.get_application_default())
worksheet = gs.open('INSERT YOUR SHEETS NAME HERE').worksheet("INSERT YOUR WORKSHEETS NAME HERE")

#retornar todas as linhas
rows = worksheet.get_all_values()
print(rows)

#converter dados em um DataFrame
pd.DataFrame.from_records(rows)
